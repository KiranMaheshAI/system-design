# %% [markdown]
# ## Revision of Observability, Monitoring and Alerting:
#
# Here's what was written across 8 sections:
#
# #### By Category:
#
# 1. Instrumentation & Collection — Telegraf, Prometheus Exporters, OpenTelemetry SDK/Collector, Fluentd/Fluent Bit, Logstash, Beats
# 2. Metrics Storage — Prometheus, InfluxDB, Thanos, Cortex/Mimir, VictoriaMetrics
# 3. Log Management — Elasticsearch, Kibana, Grafana Loki, Splunk, cloud-native options
# 4. Distributed Tracing — Jaeger, Grafana Tempo, Zipkin, cloud-managed options
# 5. Visualization — Grafana, Kibana, Grafana Cloud
# 6. Alerting & On-Call — Prometheus Alertmanager, PagerDuty, OpsGenie, Grafana OnCall, Slack/Email
# 7. Commercial All-in-One — Datadog, New Relic, Dynatrace, Honeycomb, Elastic, cloud-native — with comparison table
#
# #### Stack Combinations with architecture diagrams:
#
# 1. TIG (Telegraf → InfluxDB → Grafana) — push-based, infra/VMs
# 2. PLG (Prometheus + Loki + Grafana) — Kubernetes-native, open-source
# 3. ELK (Elasticsearch + Logstash + Kibana) — powerful log search
# 4. EFK (Elasticsearch + Fluent Bit + Kibana) — ELK but lighter
# 5. OTel + Grafana (all 3 pillars, vendor-neutral)
# 6. Datadog — commercial SaaS equivalent
# 7. Selection guide — decision tree for which stack to pick
